# %%
from thefuzz import fuzz, process
import pandas as pd

entries_df = pd.read_csv('../../data/processed/entries.csv')

entries_list = entries_df['entries'].tolist()

# fuzz_matches = process.extractOne("saint planchers", entries_list, scorer=fuzz.partial_ratio)
fuzz_matches = process.extractOne("saint planchers", entries_list)

fuzz_matches
# Out:
# ('saint planchers', 100)
