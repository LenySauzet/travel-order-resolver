# %%
import pandas as pd

df = pd.read_csv('../data/raw/communes-france-2025.csv')
cities_df = df[['nom_standard']]
cities_df.dropna()
cities_df.to_csv('../data/processed/cities.csv')
cities_df.sample(10)
# Out:
# /var/folders/mb/db31kzb10m5b8dwxr90cvmy80000gn/T/ipykernel_62472/1858670519.py:3: DtypeWarning: Columns (1,12,14,16,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/raw/communes-france-2025.csv')
#            nom_standard
# 19868         Saint-Ail
# 10510             Sizun
# 7988          Coulaures
# 11609  Montégut-Bourjac
# 12490           Hourtin
# 14386       Sainte-Luce
# 15905        Tarentaise
# 24175           Récourt
# 18201       Bouvancourt
# 26687        Fessenheim
